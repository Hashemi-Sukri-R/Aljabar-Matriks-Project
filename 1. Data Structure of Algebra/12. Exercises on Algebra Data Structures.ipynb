# %% [markdown]
# # Selesaikan soal berikut
# # What is the transpose of this vector?
# # [25]
# # [2]
# # [-3]
# # [-23]

# %%
import numpy as np

# %%
x = np.array([[25],
      [2],
      [-3],
      [-23]])
x
# Out:
# array([[ 25],
#        [  2],
#        [ -3],
#        [-23]])

# %%
x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -3, -23]])
