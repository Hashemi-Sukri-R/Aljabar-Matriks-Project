# %% [markdown]
# No. 1

# %%
import numpy as np
import torch as pt
import tensorflow as tf

# %%
# buat matrix X ukuran 2x2 menggunakan numpy
X = np.array([[6, 7], [-2, -1]])
X
# Out:
# array([[ 6,  7],
#        [-2, -1]])

# %%
# buat invers dari matrix X dan beri nama Xinv menggunakan numpy
Xinv = np.linalg.inv(X)
Xinv
# Out:
# array([[-0.125, -0.875],
#        [ 0.25 ,  0.75 ]])

# %%
# kalikan X dengan Xinv menggunakan numpy
hasil = X*Xinv
print("Hasil kali X dengan Xinv:")
print(hasil)
# Out:
# Hasil kali X dengan Xinv:
# [[-0.75  -6.125]
#  [-0.5   -0.75 ]]

# %% [markdown]
# No. 2

# %%
! pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
# selesaikan persamaan berikut menggunakan numpy, tensorflow dan pytorch
from PIL import Image
image = Image.open('soalmatriks.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=295x121>

# %%
X = np.array([[4, 2], [-5, -3]])
print("Matrix X:")
print(X)
# Out:
# Matrix X:
# [[ 4  2]
#  [-5 -3]]

# %%
Xinv = np.linalg.inv(X)
print("Invers dari Matrix X:")
print(Xinv)
# Out:
# Invers dari Matrix X:
# [[ 1.5  1. ]
#  [-2.5 -2. ]]

# %%
y = np.array([4, -7])
print("Vector y:")
print(y)
# Out:
# Vector y:
# [ 4 -7]

# %%
w = np.dot(Xinv, y)
print("Hasil akhir b dan c:", w)
# Out:
# Hasil akhir b dan c: [-1.  4.]
